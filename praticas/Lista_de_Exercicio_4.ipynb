# %% [markdown]
# # Lista de Exercício 4
# ### Introdução à Visão Computacional (SEL0339/SEL5886)
#
# **Instruções:**
#
# 1. Esta lista consiste em 3 exercícios.
# 1. Deve-se colocar comentários nos códigos desenvolvidos.
# 1. As perguntas devem ser respondidas também como comentários no arquivo.
# 1. Colocar seu nome e número USP no início da atividade.
#
# Nesta lista, serão trabalhadas uma tarefa de visão computacional utilizando o método de Otsu para **segmentação** e duas tarefas utilizando YOLO para **detecção** e **segmentação** de objetos.
#
#  <table class="tfo-notebook-buttons" align="left">
#   <td>
#     <a target="_blank" href="https://colab.research.google.com/github/LAVI-Disciplinas/SEL0339-SEL5886_2026/blob/main/praticas/Lista_de_Exercicio_4.ipynb"><img src="https://www.tensorflow.org/images/colab_logo_32px.png" />Executar no Google Colab</a>
#   </td>
#   <td>
#     <a target="_blank" href="https://github.com/LAVI-Disciplinas/SEL0339-SEL5886_2026/blob/main/praticas/Lista_de_Exercicio_4.ipynb"><img src="https://www.tensorflow.org/images/GitHub-Mark-32px.png" />Ver codigo fonte no GitHub</a>
#   </td>
# </table>

# %% [markdown]
# `Nome: `
#
# `Número USP:`

# %% [markdown]
# ## Preparação — Instalação e carregamento das imagens
#
# Antes de iniciar os exercícios, execute as células abaixo para instalar a biblioteca **Ultralytics** e baixar as imagens que serão utilizadas na prática.
#
# As imagens são:
#
# - `abobora.tif`: imagem utilizada para estudar a segmentação de objetos;
# - `carros.jpg`: imagem utilizada para estudar a detecção de objetos;
# - `mri.jpeg`: imagem de ressonância magnética, utilizada para observar o comportamento do modelo em uma imagem diferente das imagens naturais presentes no treinamento do modelo.
#
# **Atenção:** execute as células abaixo antes de iniciar os exercícios.

# %%
# !pip install -q ultralytics opencv-python matplotlib
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.7/46.7 kB 2.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 26.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.2/53.2 kB 4.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 90.0/90.0 kB 8.5 MB/s eta 0:00:00

# %%
# Download das mesmas imagens utilizadas na prática explicada
import urllib.request

try:
    urllib.request.urlretrieve(
        "https://github.com/LAVI-Disciplinas/SEL0339-SEL5886_2026/blob/main/imagens/pratica_04/carros.jpg?raw=true",
        "carros.jpg"
    )

    urllib.request.urlretrieve(
        "https://github.com/LAVI-Disciplinas/SEL0339-SEL5886_2026/blob/main/imagens/pratica_04/mri.jpeg?raw=true",
        "mri.jpeg"
    )

    urllib.request.urlretrieve(
        "https://github.com/LAVI-Disciplinas/SEL0339-SEL5886_2026/blob/main/imagens/pratica_04/abobora.tif?raw=true",
        "abobora.tif"
    )

    print("Imagens baixadas com sucesso!")

except Exception as e:
    print("[ERRO] Não foi possível fazer o download das imagens.")
    print(e)
# Out:
# Imagens baixadas com sucesso!

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
from ultralytics import YOLO
# Out:
# Creating new Ultralytics Settings v0.0.8 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/usage/settings.

# %% [markdown]
# ## 1) Influência da iluminação na segmentação (Nota 4.0/10)
#
# <center><img src="https://github.com/LAVI-Disciplinas/SEL0339-SEL5886_2026/raw/main/imagens/pratica_04/abobora_.png" width="256" height="256"></center>
#
# <center><caption><b> Figura 1:</b> Imagem abobora.tif.</b></caption></center>
#
# 1. Utilize o método de Otsu para binarizar a imagem `abobora.tif`.
# 2. Divida a imagem em 8, 32, 64 e 256 sub-imagens, aplique o método de Otsu em cada uma delas e remonte a imagem final (tenha em mente que a divisão deve ser feita de forma a segmentar em sub-regiões com o máximo de características semelhantes, de forma a se aproveitar da melhor forma o método utilizado).
# 3. Apresente a imagem original e os resultados dos itens 1 e 2 em um subplot. Coloque título em cada plot.
# 4. Comente os resultados obtidos.

# %%
## -- Seu código começa AQUI -- ##

## -- Seu código termina AQUI -- ##

## Comentários:

# %% [markdown]
# ## 2) Detecção de objetos com YOLO (3.0/10)
#
# A **detecção de objetos** consiste em localizar objetos presentes na imagem e atribuir uma classe a cada objeto encontrado. Para isso, o modelo retorna, entre outras informações, as coordenadas de uma **bounding box**, a classe prevista e um valor de confiança.
#
# Nesta questão, utilize um modelo YOLO pré-treinado para realizar a detecção nas imagens `carros.jpg` e `mri.jpeg`.
#
# O objetivo é executar o modelo, analisar suas previsões e visualizar as detecções. Observe que um modelo pré-treinado possui um conjunto de classes definido pelo seu treinamento e, portanto, não necessariamente será capaz de reconhecer corretamente objetos presentes em qualquer tipo de imagem.
#
# **Tarefa:**
#
# 1. Carregue as imagens 'carros.jpg' e 'mri.jpeg' e converta as imagens para RGB usando a biblioteca opencv. Mostre as imagens usando subplots.
# 2. Carregue os pesos pré-treinados do modelo de detecção de objetos YOLO.
# 3. Realize a inferência nas duas imagens usando o modelo e uma confiança de 50%.
# 4. Mostre o resultado da inferência para as duas imagens usando subplots. Não se esqueça de chamar o médoto plot para a saída da rede.
# 3. Compare os resultados das duas previsões.
# 4. Reduza a confiança para muito baixa, 10%, e muito alta, 90%. Faça novamente as predições usando esses níveis de confiança.
#
# As imagens podem ser carregadas de acordo com o seguinte código:
# ```
# # Carregar as imagens
# img = cv2.imread("file_name")
# img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
# ```
#
# Além disso, as imagens podem ser mostradas usando subplots:
#
# ```
# fig, axes = plt.subplots(1, 2, figsize=(28, 12))
#
# axes[0].imshow(img_carros_rgb)
# axes[0].set_title("Carros")
# axes[0].axis("off")
#
# axes[1].imshow(img_mri_rgb)
# axes[1].set_title("MRI")
# axes[1].axis("off")
#
# plt.show()
# ```
#
# Para carregar o modelo e fazer inferência:
# ```
# model_det = YOLO("yolo26n.pt")
# results = model_det(img_rgb, conf=0.50)
# ```
#
# O método `plot()` do Ultralytics pode ser utilizado para desenhar automaticamente as *bounding boxes*, os nomes das classes e os valores de confiança sobre a imagem.
#
# ```
# imagem_resultado = results[0].plot()
# plt.imshow(imagem_resultado)
# ```
#
# **Perguntas:**
# - Faça uma pesquisa online, para quais classes o modelo foi treinado ?
# - O modelo apresentou o mesmo comportamento nas duas imagens?
# - Por que um modelo pré-treinado em um determinado conjunto de classes pode apresentar dificuldades ao analisar uma imagem de outro domínio?
# - O que acontece com o modelo para baixas e altas confianças? O valor de confiança é suficiente, por si só, para garantir que uma detecção esteja correta? Justifique.

# %%
## -- Seu código começa AQUI -- ##

# Comentários:
# Responda aqui às perguntas propostas.

## -- Seu código termina AQUI -- ##

# %% [markdown]
# ## 3) Segmentação de objetos com YOLO (3.0/10)
#
# Na **segmentação de objetos**, o modelo não apenas identifica a classe e a localização do objeto, mas também estima uma **máscara** para indicar quais pixels pertencem a cada instância detectada.
#
# Nesta questão, utilize um modelo YOLO pré-treinado específico para **instance segmentation**. A estrutura geral da inferência é semelhante à utilizada na questão anterior, mas a saída passa a incluir máscaras.
#
# O modelo de segmentação utilizado deve ser carregado com pesos apropriados para segmentação, por exemplo `yolo26n-seg.pt`.
#
# ```
# # Exemplo: carregamento de um modelo YOLO para segmentação
# model_seg = YOLO("yolo26n-seg.pt")
#
# # Exemplo de inferência:
# # results_seg = model_seg(img_carros_rgb, conf=0.50)
#
# # O resultado poderá conter boxes, classes, confianças e máscaras.
#
# # Exemplo de visualização das máscaras
# imagem_segmentada = results_seg[0].plot()
#
# plt.figure(figsize=(14, 8))
# plt.imshow(imagem_segmentada)
# plt.axis("off")
# plt.show()
# ```
#
#
# Utilize o modelo de segmentação YOLO nas duas imagens utilizadas nesta lista.
#
# **Tarefa:**
#
# 1. Carregue o modelo YOLO de segmentação.
# 2. Realize a inferência na imagem `carros.jpg` e na imagem `mri.jpeg`. Use uma confiança de 50%
# 3. Mostre os resultados para as duas imagens usando subplots.
# 4. Reduza a confiança para muito baixa, 10%, e muito alta, 90%. Faça novamente as predições usando esses níveis de confiança.
# 5. Compare os resultados tanto entre as imagens quanto para com os da questão 1.
#
#
# **Perguntas:**
#
# - Qual informação adicional a segmentação fornece em relação à detecção por *bounding boxes*?
# - O modelo apresentou desempenho semelhante nas imagens de carros e MRI? Discuta considerando o domínio das imagens e as classes presentes no treinamento do modelo.
# - Cite pelo menos uma situação em que a detecção por *bounding box* seja suficiente e uma situação em que uma máscara de segmentação seja mais
# informativa.
# - O que acontece com o modelo para baixas e altas confianças? O valor de confiança é suficiente, por si só, para garantir que uma detecção esteja correta? Justifique.
#
# ### Exemplo

# %%
## -- Seu código começa AQUI -- ##

# Comentários:
# Responda aqui às perguntas propostas.

## -- Seu código termina AQUI -- ##
